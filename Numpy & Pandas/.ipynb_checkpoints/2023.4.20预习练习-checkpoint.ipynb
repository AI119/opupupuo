# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyecharts.options as opts
from pyecharts.charts import Map
# %matplotlib inline
from pyecharts.globals import CurrentConfig, NotebookType
# 配置对应的环境类型
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK
CurrentConfig.ONLINE_HOST='https://assets.pyecharts.org/assets/'

# %%
market = pd.read_excel('./data/超市.xlsx',index_col='行 ID')
market.head()
market['省/自治区'].unique()
# Out:
# array(['浙江', '四川', '江苏', '广东', '江西', '陕西', '黑龙江', '山东', '上海', '河北', '福建',
#        '安徽', '甘肃', '吉林', '辽宁', '湖北', '河南', '湖南', '北京', '重庆', '青海', '广西',
#        '天津', '云南', '海南', '贵州', '山西', '内蒙古', '宁夏', '新疆', '西藏'],
#       dtype=object)

# %%
market.groupby('地区').agg({'地区':'count'})
# Out:
#       地区
# 地区
# 东北  1666
# 中南  2581
# 华东  2944
# 华北  1369
# 西北   478
# 西南   921

# %%
#提取表格中所有省份的销售额综合并排序
#.reset_index()函数用来重设新表格的行索引
province = market[['省/自治区','销售额']].groupby('省/自治区').agg({'销售额':sum}).sort_values(by='销售额',ascending=False).reset_index()
a=province.copy()
a.head()
# Out:
#   省/自治区          销售额
# 0    山东  1586782.988
# 1    广东  1452929.513
# 2   黑龙江  1178801.162
# 3    辽宁   862569.736
# 4    河南   853574.799

# %%
x_data = province['省/自治区'].tolist()
y_data = province['销售额'].tolist()
print(x_data)
print(y_data)
# Out:
# ['山东', '广东', '黑龙江', '辽宁', '河南', '河北', '湖南', '江苏', '吉林', '安徽', '湖北', '上海', '天津', '福建', '陕西', '浙江', '山西', '北京', '四川', '广西', '重庆', '云南', '内蒙古', '江西', '甘肃', '海南', '贵州', '新疆', '宁夏', '青海', '西藏']
# [1586782.988, 1452929.513, 1178801.162, 862569.736, 853574.799, 790915.405, 723442.209, 649967.22, 640196.571, 628965.19, 621960.332, 582450.568, 549906.63, 546903.532, 457688.168, 452108.244, 423878.77, 409147.2, 400877.596, 377653.829, 361761.93200000003, 360925.768, 273453.012, 237328.7, 179270.028, 169256.843, 108141.6, 70097.02, 58121.0, 49863.38, 10015.18]

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="china")
    .add("geo", [list(z) for z in zip(x_data, y_data)])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
#     .render("geo_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="6f37b5417fb042f2811df22a7290e929" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_6f37b5417fb042f2811df22a7290e929 = echarts.init(
#                     document.getElementById('6f37b5417fb042f2811df22a7290e929'), 'white', {renderer: 'canvas'});
#                 var option_6f37b5417fb042f2811df22a7290e929 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         1586782.988
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         1452929.513
#                     ]
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": [
#                         126.661669,
#                         45.742347,
#                         1178801.162
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         862569.736
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.753602,
#                         34.765515,
#                         853574.799
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         790915.405
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         723442.209
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         649967.22
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         125.32599,
#                         43.896536,
#                         640196.571
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         628965.19
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         621960.332
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         582450.568
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         549906.63
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         546903.532
#                     ]
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": [
#                         108.954239,
#                         34.265472,
#                         457688.168
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         452108.244
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         423878.77
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         409147.2
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         400877.596
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         377653.829
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         361761.93200000003
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         102.710002,
#                         25.045806,
#                         360925.768
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         111.765617,
#                         40.817498,
#                         273453.012
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         237328.7
#                     ]
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": [
#                         103.826308,
#                         36.059421,
#                         179270.028
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         110.349228,
#                         20.017377,
#                         169256.843
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         106.70741,
#                         26.598194,
#                         108141.6
#                     ]
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": [
#                         87.627704,
#                         43.793026,
#                         70097.02
#                     ]

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

(
    Geo()
    .add_schema(maptype="china")
    .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
#     .render("geo_base.html")
)

# %%
Faker.provinces
# Out:
# ['广东省', '北京市', '上海市', '江西省', '湖南省', '浙江省', '江苏省']

# %%
Faker.values()
# Out:
# [52, 86, 34, 145, 109, 108, 43]

# %%
x = 12321
s = str(x)
if s[::-1] == str(x):
    print(True)
else:
    print(False)
# Out:
# True
