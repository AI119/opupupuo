# %%
import pandas as pd
import numpy as np
from pyecharts.globals import CurrentConfig, NotebookType
# 配置对应的环境类型
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK
CurrentConfig.ONLINE_HOST='https://assets.pyecharts.org/assets/'

# %% [markdown]
# ## 官网示例

# %% [markdown]
# #### 示例

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="Map-基本示例"))
    # .render("map_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="6f51c1e32f934fd083900b81aeba9005" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_6f51c1e32f934fd083900b81aeba9005 = echarts.init(
#                     document.getElementById('6f51c1e32f934fd083900b81aeba9005'), 'white', {renderer: 'canvas'});
#                 var option_6f51c1e32f934fd083900b81aeba9005 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 44
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": 87
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": 30
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Map-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_6f51c1e32f934fd083900b81aeba9005.setOption(option_6f51c1e32f934fd083900b81aeba9005);
#         });
#     </script>

# %% [markdown]
# #### 热力图

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.guangdong_city, Faker.values())], "广东")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-广东地图"), visualmap_opts=opts.VisualMapOpts()
    )
#     .render("map_guangdong.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="3a22a6165e544408bdc140f1f060a4c4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_3a22a6165e544408bdc140f1f060a4c4 = echarts.init(
#                     document.getElementById('3a22a6165e544408bdc140f1f060a4c4'), 'white', {renderer: 'canvas'});
#                 var option_3a22a6165e544408bdc140f1f060a4c4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "\u5e7f\u4e1c",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": 130
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Map-\u5e7f\u4e1c\u5730\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_3a22a6165e544408bdc140f1f060a4c4.setOption(option_3a22a6165e544408bdc140f1f060a4c4);
#         });
#     </script>

# %% [markdown]
# ### 雷达图示例

# %%
import pyecharts.options as opts
from pyecharts.charts import Radar

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.apache.org/examples/editor.html?c=radar

目前无法实现的功能:

1、雷达图周围的图例的 textStyle 暂时无法设置背景颜色
"""
v1 = [[4300, 10000, 28000, 35000, 50000, 19000]]
v2 = [[5000, 14000, 28000, 31000, 42000, 21000]]

(
    Radar(init_opts=opts.InitOpts(bg_color="#CCCCCC"))
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name="销售（sales）", max_=6500),
            opts.RadarIndicatorItem(name="管理（Administration）", max_=16000),
            opts.RadarIndicatorItem(name="信息技术（Information Technology）", max_=30000),
            opts.RadarIndicatorItem(name="客服（Customer Support）", max_=38000),
            opts.RadarIndicatorItem(name="研发（Development）", max_=52000),
            opts.RadarIndicatorItem(name="市场（Marketing）", max_=25000),
        ],
        splitarea_opt=opts.SplitAreaOpts(
            is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
        ),
        textstyle_opts=opts.TextStyleOpts(color="#fff"),
    )
    .add(
        series_name="预算分配（Allocated Budget）",
        data=v1,
        linestyle_opts=opts.LineStyleOpts(color="#CD0000"),
    )
    .add(
        series_name="实际开销（Actual Spending）",
        data=v2,
        linestyle_opts=opts.LineStyleOpts(color="#5CACEE"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="基础雷达图"), legend_opts=opts.LegendOpts()
    )
#     .render("basic_radar_chart.html")
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e59a1b6c238142a6a66af609972c0638" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e59a1b6c238142a6a66af609972c0638 = echarts.init(
#                     document.getElementById('e59a1b6c238142a6a66af609972c0638'), 'white', {renderer: 'canvas'});
#                 var option_e59a1b6c238142a6a66af609972c0638 = {
#     "backgroundColor": "#CCCCCC",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09",
#             "data": [
#                 [
#                     4300,
#                     10000,
#                     28000,
#                     35000,
#                     50000,
#                     19000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#CD0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09",
#             "data": [
#                 [
#                     5000,
#                     14000,
#                     28000,
#                     31000,
#                     42000,
#                     21000
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#5CACEE"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09",
#                 "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09"
#             ],
#             "selected": {
#                 "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09": true,
#                 "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "radar": [
#         {
#             "indicator": [
#                 {
#                     "name": "\u9500\u552e\uff08sales\uff09",
#                     "max": 6500
#                 },
#                 {
#                     "name": "\u7ba1\u7406\uff08Administration\uff09",
#                     "max": 16000
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u6280\u672f\uff08Information Technology\uff09",
#                     "max": 30000
#                 },
#                 {
#                     "name": "\u5ba2\u670d\uff08Customer Support\uff09",
#                     "max": 38000
#                 },
#                 {
#                     "name": "\u7814\u53d1\uff08Development\uff09",
#                     "max": 52000
#                 },
#                 {
#                     "name": "\u5e02\u573a\uff08Marketing\uff09",
#                     "max": 25000
#                 }
#             ],
#             "startAngle": 90,
#             "name": {
#                 "textStyle": {
#                     "color": "#fff"
#                 }
#             },
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             },
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u57fa\u7840\u96f7\u8fbe\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e59a1b6c238142a6a66af609972c0638.setOption(option_e59a1b6c238142a6a66af609972c0638);
#         });
#     </script>

# %% [markdown]
# ## 处理数据

# %%
data1 = pd.read_excel('./data/超市.xlsx')
data1.head()
# Out:
#    行 ID            订单 ID       订单日期       发货日期 邮寄方式     客户 ID 客户名称   细分  城市  \
# 0     1  US-2018-1357144 2018-04-27 2018-04-29   二级  曾惠-14485   曾惠   公司  杭州
# 1     2  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者  内江
# 2     3  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者  内江
# 3     4  US-2018-3017568 2018-12-09 2018-12-13  标准级  宋良-17170   宋良   公司  镇江
# 4     5  CN-2017-2975416 2017-05-31 2017-06-02   二级  万兰-15730   万兰  消费者  汕头
#
#   省/自治区  国家  地区            产品 ID    类别  子类别                产品名称       销售额  数量  \
# 0    浙江  中国  华东  办公用-用品-10002717  办公用品   用品      Fiskars 剪刀, 蓝色   129.696   2
# 1    四川  中国  西南  办公用-信封-10004832  办公用品   信封  GlobeWeis 搭扣信封, 红色   125.440   2
# 2    四川  中国  西南  办公用-装订-10001505  办公用品  装订机  Cardinal 孔加固材料, 回收    31.920   2
# 3    江苏  中国  华东  办公用-用品-10003746  办公用品   用品    Kleencut 开信刀, 工业   321.216   4
# 4    广东  中国  中南  办公用-器具-10003452  办公用品   器具  KitchenAid 搅拌机, 黑色  1375.920   3
#
#     折扣       利润
# 0  0.4  -60.704
# 1  0.0   42.560
# 2  0.4    4.200
# 3  0.4  -27.104
# 4  0.0  550.200

# %%
data_1 = pd.DataFrame(data1.groupby(['省/自治区'])['销售额'].sum()).reset_index()
data_1
# Out:
#    省/自治区          销售额
# 0     上海   582450.568
# 1     云南   360925.768
# 2    内蒙古   273453.012
# 3     北京   409147.200
# 4     吉林   640196.571
# 5     四川   400877.596
# 6     天津   549906.630
# 7     宁夏    58121.000
# 8     安徽   628965.190
# 9     山东  1586782.988
# 10    山西   423878.770
# 11    广东  1452929.513
# 12    广西   377653.829
# 13    新疆    70097.020
# 14    江苏   649967.220
# 15    江西   237328.700
# 16    河北   790915.405
# 17    河南   853574.799
# 18    浙江   452108.244
# 19    海南   169256.843
# 20    湖北   621960.332
# 21    湖南   723442.209
# 22    甘肃   179270.028
# 23    福建   546903.532
# 24    西藏    10015.180
# 25    贵州   108141.600
# 26    辽宁   862569.736
# 27    重庆   361761.932
# 28    陕西   457688.168
# 29    青海    49863.380
# 30   黑龙江  1178801.162

# %% [markdown]
# ### 雷达图

# %%
data_2 = data1[['细分','地区','销售额']].groupby(['细分','地区']).agg({'销售额':'sum'}).unstack()
data_2['销售额']
# Out:
# 地区             东北           中南           华东           华北          西北  \
# 细分
# 公司     834842.827  1335665.324  1454715.808   804769.469  253458.184
# 小型企业   522739.035   743813.007   942432.372   422100.987  103523.308
# 消费者   1323985.607  2057936.762  2287358.262  1220430.561  458058.104
#
# 地区            西南
# 细分
# 公司    469341.684
# 小型企业  156479.932
# 消费者   677302.892

# %%
from pyecharts import options as opts
from pyecharts.charts import Radar
v1 = [data_2['销售额'].loc['公司',:].tolist()]
v2 = [data_2['销售额'].loc['小型企业',:].tolist()]
v3 = [data_2['销售额'].loc['消费者',:].tolist()]
c = (
Radar()
.add_schema(
schema=[
opts.RadarIndicatorItem(name="东北", max_=2000000),
opts.RadarIndicatorItem(name="中南", max_=2300000),
opts.RadarIndicatorItem(name="华东", max_=2500000),
opts.RadarIndicatorItem(name="华北", max_=1500000),
opts.RadarIndicatorItem(name="西北", max_=500000),
opts.RadarIndicatorItem(name="西南", max_=1000000),
]
)
.add("公司", v1)
.add("小型企业", v2)
.add("消费者", v3)
.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
.set_global_opts(
legend_opts=opts.LegendOpts(selected_mode="single"),
title_opts=opts.TitleOpts(title="客户细分不同地区的销售额"),
)
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c17a25938fe4d06a34765b0a22839b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c17a25938fe4d06a34765b0a22839b4 = echarts.init(
#                     document.getElementById('4c17a25938fe4d06a34765b0a22839b4'), 'white', {renderer: 'canvas'});
#                 var option_4c17a25938fe4d06a34765b0a22839b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u516c\u53f8",
#             "data": [
#                 [
#                     834842.827,
#                     1335665.324,
#                     1454715.808,
#                     804769.469,
#                     253458.184,
#                     469341.684
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5c0f\u578b\u4f01\u4e1a",
#             "data": [
#                 [
#                     522739.035,
#                     743813.007,
#                     942432.372,
#                     422100.987,
#                     103523.308,
#                     156479.932
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u6d88\u8d39\u8005",
#             "data": [
#                 [
#                     1323985.607,
#                     2057936.762,
#                     2287358.262,
#                     1220430.561,
#                     458058.104,
#                     677302.892
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8",
#                 "\u5c0f\u578b\u4f01\u4e1a",
#                 "\u6d88\u8d39\u8005"
#             ],
#             "selected": {
#                 "\u516c\u53f8": true,
#                 "\u5c0f\u578b\u4f01\u4e1a": true,
#                 "\u6d88\u8d39\u8005": true
#             },
#             "selectedMode": "single",
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "radar": [
#         {
#             "indicator": [
#                 {
#                     "name": "\u4e1c\u5317",
#                     "max": 2000000
#                 },
#                 {
#                     "name": "\u4e2d\u5357",
#                     "max": 2300000
#                 },
#                 {
#                     "name": "\u534e\u4e1c",
#                     "max": 2500000
#                 },
#                 {
#                     "name": "\u534e\u5317",
#                     "max": 1500000
#                 },
#                 {
#                     "name": "\u897f\u5317",
#                     "max": 500000
#                 },
#                 {
#                     "name": "\u897f\u5357",
#                     "max": 1000000
#                 }
#             ],
#             "startAngle": 90,
#             "name": {
#                 "textStyle": {}
#             },
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 0
#                 }
#             },
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u5ba2\u6237\u7ec6\u5206\u4e0d\u540c\u5730\u533a\u7684\u9500\u552e\u989d",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_4c17a25938fe4d06a34765b0a22839b4.setOption(option_4c17a25938fe4d06a34765b0a22839b4);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import Radar

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.apache.org/examples/editor.html?c=radar

目前无法实现的功能:

1、雷达图周围的图例的 textStyle 暂时无法设置背景颜色
"""
v1 = [data_2['销售额'].loc['公司',:].tolist()]
v2 = [data_2['销售额'].loc['小型企业',:].tolist()]
v3 = [data_2['销售额'].loc['消费者',:].tolist()]

(
    Radar(init_opts=opts.InitOpts(bg_color="#CCCCCC"))
    .add_schema(
        schema=[
            opts.RadarIndicatorItem(name="东北", ),
opts.RadarIndicatorItem(name="中南", ),
opts.RadarIndicatorItem(name="华东", ),
opts.RadarIndicatorItem(name="华北", ),
opts.RadarIndicatorItem(name="西北",),
opts.RadarIndicatorItem(name="西南", ),
        ],
        splitarea_opt=opts.SplitAreaOpts(
            is_show=True, areastyle_opts=opts.AreaStyleOpts(opacity=1)
        ),
        textstyle_opts=opts.TextStyleOpts(color="#fff"),
    )
    .add(
        series_name="预算分配（Allocated Budget）",
        data=v1,
        linestyle_opts=opts.LineStyleOpts(color="#CD0000"),
    )
    .add(
        series_name="实际开销（Actual Spending）",
        data=v2,
        linestyle_opts=opts.LineStyleOpts(color="#5CACEE"),
    )
    .add(
        series_name="111（Actual Spending）",
        data=v3,
        linestyle_opts=opts.LineStyleOpts(color="#5CACEE"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="基础雷达图"), legend_opts=opts.LegendOpts()
    )
#     .render("basic_radar_chart.html")
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e2434213c4a34e5487fa15518599e161" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e2434213c4a34e5487fa15518599e161 = echarts.init(
#                     document.getElementById('e2434213c4a34e5487fa15518599e161'), 'white', {renderer: 'canvas'});
#                 var option_e2434213c4a34e5487fa15518599e161 = {
#     "backgroundColor": "#CCCCCC",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09",
#             "data": [
#                 [
#                     834842.827,
#                     1335665.324,
#                     1454715.808,
#                     804769.469,
#                     253458.184,
#                     469341.684
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#CD0000"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09",
#             "data": [
#                 [
#                     522739.035,
#                     743813.007,
#                     942432.372,
#                     422100.987,
#                     103523.308,
#                     156479.932
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#5CACEE"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "radar",
#             "name": "111\uff08Actual Spending\uff09",
#             "data": [
#                 [
#                     1323985.607,
#                     2057936.762,
#                     2287358.262,
#                     1220430.561,
#                     458058.104,
#                     677302.892
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "normal": {}
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#5CACEE"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09",
#                 "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09",
#                 "111\uff08Actual Spending\uff09"
#             ],
#             "selected": {
#                 "\u9884\u7b97\u5206\u914d\uff08Allocated Budget\uff09": true,
#                 "\u5b9e\u9645\u5f00\u9500\uff08Actual Spending\uff09": true,
#                 "111\uff08Actual Spending\uff09": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "radar": [
#         {
#             "indicator": [
#                 {
#                     "name": "\u4e1c\u5317"
#                 },
#                 {
#                     "name": "\u4e2d\u5357"
#                 },
#                 {
#                     "name": "\u534e\u4e1c"
#                 },
#                 {
#                     "name": "\u534e\u5317"
#                 },
#                 {
#                     "name": "\u897f\u5317"
#                 },
#                 {
#                     "name": "\u897f\u5357"
#                 }
#             ],
#             "startAngle": 90,
#             "name": {
#                 "textStyle": {
#                     "color": "#fff"
#                 }
#             },
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             },
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u57fa\u7840\u96f7\u8fbe\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e2434213c4a34e5487fa15518599e161.setOption(option_e2434213c4a34e5487fa15518599e161);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

c = (
    Funnel()
    .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
    # .render("funnel_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5c6c9c18bb734dfab213d8e3f1518da7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5c6c9c18bb734dfab213d8e3f1518da7 = echarts.init(
#                     document.getElementById('5c6c9c18bb734dfab213d8e3f1518da7'), 'white', {renderer: 'canvas'});
#                 var option_5c6c9c18bb734dfab213d8e3f1518da7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 126
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6bdb\u8863",
#                 "\u889c\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u9886\u5e26",
#                 "\u886c\u886b",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863"
#             ],
#             "selected": {
#                 "\u886c\u886b": true,
#                 "\u6bdb\u8863": true,
#                 "\u9886\u5e26": true,
#                 "\u88e4\u5b50": true,
#                 "\u98ce\u8863": true,
#                 "\u9ad8\u8ddf\u978b": true,
#                 "\u889c\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_5c6c9c18bb734dfab213d8e3f1518da7.setOption(option_5c6c9c18bb734dfab213d8e3f1518da7);
#         });
#     </script>

# %%
data2 = pd.read_excel('./data/漏斗.xlsx')
data2
# Out:
#   用户主要行为     用户数
# 0    DAU  700000
# 1     登录  500000
# 2  加入购物车  300000
# 3   生成订单  210000
# 4     支付  150000
# 5   完成交易  140000

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

c = (
    Funnel()
    .add("商品", [list(z) for z in zip(data2['用户主要行为'].tolist(), data2['用户数'].tolist())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
    # .render("funnel_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f03e034b57aa4586988f2a6c29678d91" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f03e034b57aa4586988f2a6c29678d91 = echarts.init(
#                     document.getElementById('f03e034b57aa4586988f2a6c29678d91'), 'white', {renderer: 'canvas'});
#                 var option_f03e034b57aa4586988f2a6c29678d91 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "DAU",
#                     "value": 700000
#                 },
#                 {
#                     "name": "\u767b\u5f55",
#                     "value": 500000
#                 },
#                 {
#                     "name": "\u52a0\u5165\u8d2d\u7269\u8f66",
#                     "value": 300000
#                 },
#                 {
#                     "name": "\u751f\u6210\u8ba2\u5355",
#                     "value": 210000
#                 },
#                 {
#                     "name": "\u652f\u4ed8",
#                     "value": 150000
#                 },
#                 {
#                     "name": "\u5b8c\u6210\u4ea4\u6613",
#                     "value": 140000
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b8c\u6210\u4ea4\u6613",
#                 "\u652f\u4ed8",
#                 "\u52a0\u5165\u8d2d\u7269\u8f66",
#                 "\u751f\u6210\u8ba2\u5355",
#                 "\u767b\u5f55",
#                 "DAU"
#             ],
#             "selected": {
#                 "DAU": true,
#                 "\u767b\u5f55": true,
#                 "\u52a0\u5165\u8d2d\u7269\u8f66": true,
#                 "\u751f\u6210\u8ba2\u5355": true,
#                 "\u652f\u4ed8": true,
#                 "\u5b8c\u6210\u4ea4\u6613": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_f03e034b57aa4586988f2a6c29678d91.setOption(option_f03e034b57aa4586988f2a6c29678d91);
#         });
#     </script>

# %% [markdown]
# ### 象形图官网示例

# %%
from pyecharts import options as opts
from pyecharts.charts import PictorialBar
from pyecharts.globals import SymbolType

location = ["山西", "四川", "西藏", "北京", "上海", "内蒙古", "云南", "黑龙江", "广东", "福建"]
values = [13, 42, 67, 81, 86, 94, 166, 220, 249, 262]

c = (
    PictorialBar()
    .add_xaxis(location)
    .add_yaxis(
        "",
        values,
        label_opts=opts.LabelOpts(is_show=False),
        symbol_size=18,
        symbol_repeat="fixed",
        symbol_offset=[0, 0],
        is_symbol_clip=True,
        symbol=SymbolType.ROUND_RECT,
    )
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="PictorialBar-各省份人口数量（虚假数据）"),
        xaxis_opts=opts.AxisOpts(is_show=False),
        yaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_show=False),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(opacity=0)
            ),
        ),
    )
    # .render("pictorialbar_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2f8589d8a36b45419052aa22058ac140" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2f8589d8a36b45419052aa22058ac140 = echarts.init(
#                     document.getElementById('2f8589d8a36b45419052aa22058ac140'), 'white', {renderer: 'canvas'});
#                 var option_2f8589d8a36b45419052aa22058ac140 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 13,
#                 42,
#                 67,
#                 81,
#                 86,
#                 94,
#                 166,
#                 220,
#                 249,
#                 262
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u897f",
#                 "\u56db\u5ddd",
#                 "\u897f\u85cf",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5185\u8499\u53e4",
#                 "\u4e91\u5357",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5e7f\u4e1c",
#                 "\u798f\u5efa"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "PictorialBar-\u5404\u7701\u4efd\u4eba\u53e3\u6570\u91cf\uff08\u865a\u5047\u6570\u636e\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_2f8589d8a36b45419052aa22058ac140.setOption(option_2f8589d8a36b45419052aa22058ac140);
#         });
#     </script>

# %%
data3 = data1.groupby('地区')[['销售额']].sum().reset_index()
data3
# Out:
#    地区          销售额
# 0  东北  2681567.469
# 1  中南  4137415.093
# 2  华东  4684506.442
# 3  华北  2447301.017
# 4  西北   815039.596
# 5  西南  1303124.508

# %%
location = data3['地区'].tolist()
values = data3['销售额'].tolist()
png = {
  'reindeer':
    'path://M-22.788,24.521c2.08-0.986,3.611-3.905,4.984-5.892 c-2.686,2.782-5.047,5.884-9.102,7.312c-0.992,0.005-0.25-2.016,0.34-2.362l1.852-0.41c0.564-0.218,0.785-0.842,0.902-1.347 c2.133-0.727,4.91-4.129,6.031-6.194c1.748-0.7,4.443-0.679,5.734-2.293c1.176-1.468,0.393-3.992,1.215-6.557 c0.24-0.754,0.574-1.581,1.008-2.293c-0.611,0.011-1.348-0.061-1.959-0.608c-1.391-1.245-0.785-2.086-1.297-3.313 c1.684,0.744,2.5,2.584,4.426,2.586C-8.46,3.012-8.255,2.901-8.04,2.824c6.031-1.952,15.182-0.165,19.498-3.937 c1.15-3.933-1.24-9.846-1.229-9.938c0.008-0.062-1.314-0.004-1.803-0.258c-1.119-0.771-6.531-3.75-0.17-3.33 c0.314-0.045,0.943,0.259,1.439,0.435c-0.289-1.694-0.92-0.144-3.311-1.946c0,0-1.1-0.855-1.764-1.98 c-0.836-1.09-2.01-2.825-2.992-4.031c-1.523-2.476,1.367,0.709,1.816,1.108c1.768,1.704,1.844,3.281,3.232,3.983 c0.195,0.203,1.453,0.164,0.926-0.468c-0.525-0.632-1.367-1.278-1.775-2.341c-0.293-0.703-1.311-2.326-1.566-2.711 c-0.256-0.384-0.959-1.718-1.67-2.351c-1.047-1.187-0.268-0.902,0.521-0.07c0.789,0.834,1.537,1.821,1.672,2.023 c0.135,0.203,1.584,2.521,1.725,2.387c0.102-0.259-0.035-0.428-0.158-0.852c-0.125-0.423-0.912-2.032-0.961-2.083 c-0.357-0.852-0.566-1.908-0.598-3.333c0.4-2.375,0.648-2.486,0.549-0.705c0.014,1.143,0.031,2.215,0.602,3.247 c0.807,1.496,1.764,4.064,1.836,4.474c0.561,3.176,2.904,1.749,2.281-0.126c-0.068-0.446-0.109-2.014-0.287-2.862 c-0.18-0.849-0.219-1.688-0.113-3.056c0.066-1.389,0.232-2.055,0.277-2.299c0.285-1.023,0.4-1.088,0.408,0.135 c-0.059,0.399-0.131,1.687-0.125,2.655c0.064,0.642-0.043,1.768,0.172,2.486c0.654,1.928-0.027,3.496,1,3.514 c1.805-0.424,2.428-1.218,2.428-2.346c-0.086-0.704-0.121-0.843-0.031-1.193c0.221-0.568,0.359-0.67,0.312-0.076 c-0.055,0.287,0.031,0.533,0.082,0.794c0.264,1.197,0.912,0.114,1.283-0.782c0.15-0.238,0.539-2.154,0.545-2.522 c-0.023-0.617,0.285-0.645,0.309,0.01c0.064,0.422-0.248,2.646-0.205,2.334c-0.338,1.24-1.105,3.402-3.379,4.712 c-0.389,0.12-1.186,1.286-3.328,2.178c0,0,1.729,0.321,3.156,0.246c1.102-0.19,3.707-0.027,4.654,0.269 c1.752,0.494,1.531-0.053,4.084,0.164c2.26-0.4,2.154,2.391-1.496,3.68c-2.549,1.405-3.107,1.475-2.293,2.984 c3.484,7.906,2.865,13.183,2.193,16.466c2.41,0.271,5.732-0.62,7.301,0.725c0.506,0.333,0.648,1.866-0.457,2.86 c-4.105,2.745-9.283,7.022-13.904,7.662c-0.977-0.194,0.156-2.025,0.803-2.247l1.898-0.03c0.596-0.101,0.936-0.669,1.152-1.139 c3.16-0.404,5.045-3.775,8.246-4.818c-4.035-0.718-9.588,3.981-12.162,1.051c-5.043,1.423-11.449,1.84-15.895,1.111 c-3.105,2.687-7.934,4.021-12.115,5.866c-3.271,3.511-5.188,8.086-9.967,10.414c-0.986,0.119-0.48-1.974,0.066-2.385l1.795-0.618 C-22.995,25.682-22.849,25.035-22.788,24.521z',
  'plane':
    'path://M1.112,32.559l2.998,1.205l-2.882,2.268l-2.215-0.012L1.112,32.559z M37.803,23.96 c0.158-0.838,0.5-1.509,0.961-1.904c-0.096-0.037-0.205-0.071-0.344-0.071c-0.777-0.005-2.068-0.009-3.047-0.009 c-0.633,0-1.217,0.066-1.754,0.18l2.199,1.804H37.803z M39.738,23.036c-0.111,0-0.377,0.325-0.537,0.924h1.076 C40.115,23.361,39.854,23.036,39.738,23.036z M39.934,39.867c-0.166,0-0.674,0.705-0.674,1.986s0.506,1.986,0.674,1.986 s0.672-0.705,0.672-1.986S40.102,39.867,39.934,39.867z M38.963,38.889c-0.098-0.038-0.209-0.07-0.348-0.073 c-0.082,0-0.174,0-0.268-0.001l-7.127,4.671c0.879,0.821,2.42,1.417,4.348,1.417c0.979,0,2.27-0.006,3.047-0.01 c0.139,0,0.25-0.034,0.348-0.072c-0.646-0.555-1.07-1.643-1.07-2.967C37.891,40.529,38.316,39.441,38.963,38.889z M32.713,23.96 l-12.37-10.116l-4.693-0.004c0,0,4,8.222,4.827,10.121H32.713z M59.311,32.374c-0.248,2.104-5.305,3.172-8.018,3.172H39.629 l-25.325,16.61L9.607,52.16c0,0,6.687-8.479,7.95-10.207c1.17-1.6,3.019-3.699,3.027-6.407h-2.138 c-5.839,0-13.816-3.789-18.472-5.583c-2.818-1.085-2.396-4.04-0.031-4.04h0.039l-3.299-11.371h3.617c0,0,4.352,5.696,5.846,7.5 c2,2.416,4.503,3.678,8.228,3.87h30.727c2.17,0,4.311,0.417,6.252,1.046c3.49,1.175,5.863,2.7,7.199,4.027 C59.145,31.584,59.352,32.025,59.311,32.374z M22.069,30.408c0-0.815-0.661-1.475-1.469-1.475c-0.812,0-1.471,0.66-1.471,1.475 s0.658,1.475,1.471,1.475C21.408,31.883,22.069,31.224,22.069,30.408z M27.06,30.408c0-0.815-0.656-1.478-1.466-1.478 c-0.812,0-1.471,0.662-1.471,1.478s0.658,1.477,1.471,1.477C26.404,31.885,27.06,31.224,27.06,30.408z M32.055,30.408 c0-0.815-0.66-1.475-1.469-1.475c-0.808,0-1.466,0.66-1.466,1.475s0.658,1.475,1.466,1.475 C31.398,31.883,32.055,31.224,32.055,30.408z M37.049,30.408c0-0.815-0.658-1.478-1.467-1.478c-0.812,0-1.469,0.662-1.469,1.478 s0.656,1.477,1.469,1.477C36.389,31.885,37.049,31.224,37.049,30.408z M42.039,30.408c0-0.815-0.656-1.478-1.465-1.478 c-0.811,0-1.469,0.662-1.469,1.478s0.658,1.477,1.469,1.477C41.383,31.885,42.039,31.224,42.039,30.408z M55.479,30.565 c-0.701-0.436-1.568-0.896-2.627-1.347c-0.613,0.289-1.551,0.476-2.73,0.476c-1.527,0-1.639,2.263,0.164,2.316 C52.389,32.074,54.627,31.373,55.479,30.565z',
  'train':
    'path://M67.335,33.596L67.335,33.596c-0.002-1.39-1.153-3.183-3.328-4.218h-9.096v-2.07h5.371 c-4.939-2.07-11.199-4.141-14.89-4.141H19.72v12.421v5.176h38.373c4.033,0,8.457-1.035,9.142-5.176h-0.027 c0.076-0.367,0.129-0.751,0.129-1.165L67.335,33.596L67.335,33.596z M27.999,30.413h-3.105v-4.141h3.105V30.413z M35.245,30.413 h-3.104v-4.141h3.104V30.413z M42.491,30.413h-3.104v-4.141h3.104V30.413z M49.736,30.413h-3.104v-4.141h3.104V30.413z  M14.544,40.764c1.143,0,2.07-0.927,2.07-2.07V35.59V25.237c0-1.145-0.928-2.07-2.07-2.07H-9.265c-1.143,0-2.068,0.926-2.068,2.07 v10.351v3.105c0,1.144,0.926,2.07,2.068,2.07H14.544L14.544,40.764z M8.333,26.272h3.105v4.141H8.333V26.272z M1.087,26.272h3.105 v4.141H1.087V26.272z M-6.159,26.272h3.105v4.141h-3.105V26.272z M-9.265,41.798h69.352v1.035H-9.265V41.798z',
  'ship': 'path://M16.678,17.086h9.854l-2.703,5.912c5.596,2.428,11.155,5.575,16.711,8.607c3.387,1.847,6.967,3.75,10.541,5.375 v-6.16l-4.197-2.763v-5.318L33.064,12.197h-11.48L20.43,15.24h-4.533l-1.266,3.286l0.781,0.345L16.678,17.086z M49.6,31.84 l0.047,1.273L27.438,20.998l0.799-1.734L49.6,31.84z M33.031,15.1l12.889,8.82l0.027,0.769L32.551,16.1L33.031,15.1z M22.377,14.045 h9.846l-1.539,3.365l-2.287-1.498h1.371l0.721-1.352h-2.023l-0.553,1.037l-0.541-0.357h-0.34l0.359-0.684h-2.025l-0.361,0.684 h-3.473L22.377,14.045z M23.695,20.678l-0.004,0.004h0.004V20.678z M24.828,18.199h-2.031l-0.719,1.358h2.029L24.828,18.199z  M40.385,34.227c-12.85-7.009-25.729-14.667-38.971-12.527c1.26,8.809,9.08,16.201,8.213,24.328 c-0.553,4.062-3.111,0.828-3.303,7.137c15.799,0,32.379,0,48.166,0l0.066-4.195l1.477-7.23 C50.842,39.812,45.393,36.961,40.385,34.227z M13.99,35.954c-1.213,0-2.195-1.353-2.195-3.035c0-1.665,0.98-3.017,2.195-3.017 c1.219,0,2.195,1.352,2.195,3.017C16.186,34.604,15.213,35.954,13.99,35.954z M23.691,20.682h-2.02l-0.588,1.351h2.023 L23.691,20.682z M19.697,18.199l-0.721,1.358h2.025l0.727-1.358H19.697z',
  'car': 'path://M49.592,40.883c-0.053,0.354-0.139,0.697-0.268,0.963c-0.232,0.475-0.455,0.519-1.334,0.475 c-1.135-0.053-2.764,0-4.484,0.068c0,0.476,0.018,0.697,0.018,0.697c0.111,1.299,0.697,1.342,0.931,1.342h3.7 c0.326,0,0.628,0,0.861-0.154c0.301-0.196,0.43-0.772,0.543-1.78c0.017-0.146,0.025-0.336,0.033-0.56v-0.01 c0-0.068,0.008-0.154,0.008-0.25V41.58l0,0C49.6,41.348,49.6,41.09,49.592,40.883L49.592,40.883z M6.057,40.883 c0.053,0.354,0.137,0.697,0.268,0.963c0.23,0.475,0.455,0.519,1.334,0.475c1.137-0.053,2.762,0,4.484,0.068 c0,0.476-0.018,0.697-0.018,0.697c-0.111,1.299-0.697,1.342-0.93,1.342h-3.7c-0.328,0-0.602,0-0.861-0.154 c-0.309-0.18-0.43-0.772-0.541-1.78c-0.018-0.146-0.027-0.336-0.035-0.56v-0.01c0-0.068-0.008-0.154-0.008-0.25V41.58l0,0 C6.057,41.348,6.057,41.09,6.057,40.883L6.057,40.883z M49.867,32.766c0-2.642-0.344-5.224-0.482-5.507 c-0.104-0.207-0.766-0.749-2.271-1.773c-1.522-1.042-1.487-0.887-1.766-1.566c0.25-0.078,0.492-0.224,0.639-0.241 c0.326-0.034,0.345,0.274,1.023,0.274c0.68,0,2.152-0.18,2.453-0.48c0.301-0.303,0.396-0.405,0.396-0.672 c0-0.268-0.156-0.818-0.447-1.146c-0.293-0.327-1.541-0.49-2.273-0.585c-0.729-0.095-0.834,0-1.022,0.121 c-0.304,0.189-0.32,1.919-0.32,1.919l-0.713,0.018c-0.465-1.146-1.11-3.452-2.117-5.269c-1.103-1.979-2.256-2.599-2.737-2.754 c-0.474-0.146-0.904-0.249-4.131-0.576c-3.298-0.344-5.922-0.388-8.262-0.388c-2.342,0-4.967,0.052-8.264,0.388 c-3.229,0.336-3.66,0.43-4.133,0.576s-1.633,0.775-2.736,2.754c-1.006,1.816-1.652,4.123-2.117,5.269L9.87,23.109 c0,0-0.008-1.729-0.318-1.919c-0.189-0.121-0.293-0.225-1.023-0.121c-0.732,0.104-1.98,0.258-2.273,0.585 c-0.293,0.327-0.447,0.878-0.447,1.146c0,0.267,0.094,0.379,0.396,0.672c0.301,0.301,1.773,0.48,2.453,0.48 c0.68,0,0.697-0.309,1.023-0.274c0.146,0.018,0.396,0.163,0.637,0.241c-0.283,0.68-0.24,0.524-1.764,1.566 c-1.506,1.033-2.178,1.566-2.271,1.773c-0.139,0.283-0.482,2.865-0.482,5.508s0.189,5.02,0.189,5.86c0,0.354,0,0.976,0.076,1.565 c0.053,0.354,0.129,0.697,0.268,0.966c0.232,0.473,0.447,0.516,1.334,0.473c1.137-0.051,2.779,0,4.477,0.07 c1.135,0.043,2.297,0.086,3.33,0.11c2.582,0.051,1.826-0.379,2.928-0.36c1.102,0.016,5.447,0.196,9.424,0.196 c3.976,0,8.332-0.182,9.423-0.196c1.102-0.019,0.346,0.411,2.926,0.36c1.033-0.018,2.195-0.067,3.332-0.11 c1.695-0.062,3.348-0.121,4.477-0.07c0.886,0.043,1.103,0,1.332-0.473c0.132-0.269,0.218-0.611,0.269-0.966 c0.086-0.592,0.078-1.213,0.078-1.565C49.678,37.793,49.867,35.408,49.867,32.766L49.867,32.766z M13.219,19.735 c0.412-0.964,1.652-2.9,2.256-3.244c0.145-0.087,1.426-0.491,4.637-0.706c2.953-0.198,6.217-0.276,7.73-0.276 c1.513,0,4.777,0.078,7.729,0.276c3.201,0.215,4.502,0.611,4.639,0.706c0.775,0.533,1.842,2.28,2.256,3.244 c0.412,0.965,0.965,2.858,0.861,3.116c-0.104,0.258,0.104,0.388-1.291,0.275c-1.387-0.103-10.088-0.216-14.185-0.216 c-4.088,0-12.789,0.113-14.184,0.216c-1.395,0.104-1.188-0.018-1.291-0.275C12.254,22.593,12.805,20.708,13.219,19.735 L13.219,19.735z M16.385,30.511c-0.619,0.155-0.988,0.491-1.764,0.482c-0.775,0-2.867-0.353-3.314-0.371 c-0.447-0.017-0.842,0.302-1.076,0.362c-0.23,0.06-0.688-0.104-1.377-0.318c-0.688-0.216-1.092-0.155-1.316-1.094 c-0.232-0.93,0-2.264,0-2.264c1.488-0.068,2.928,0.069,5.621,0.826c2.693,0.758,4.191,2.213,4.191,2.213 S17.004,30.357,16.385,30.511L16.385,30.511z M36.629,37.293c-1.23,0.164-6.386,0.207-8.794,0.207c-2.412,0-7.566-0.051-8.799-0.207 c-1.256-0.164-2.891-1.67-1.764-2.865c1.523-1.627,1.24-1.576,4.701-2.023C24.967,32.018,27.239,32,27.834,32 c0.584,0,2.865,0.025,5.859,0.404c3.461,0.447,3.178,0.396,4.699,2.022C39.521,35.623,37.887,37.129,36.629,37.293L36.629,37.293z  M48.129,29.582c-0.232,0.93-0.629,0.878-1.318,1.093c-0.688,0.216-1.145,0.371-1.377,0.319c-0.231-0.053-0.627-0.371-1.074-0.361 c-0.448,0.018-2.539,0.37-3.313,0.37c-0.772,0-1.146-0.328-1.764-0.481c-0.621-0.154-0.966-0.154-0.966-0.154 s1.49-1.464,4.191-2.213c2.693-0.758,4.131-0.895,5.621-0.826C48.129,27.309,48.361,28.643,48.129,29.582L48.129,29.582z'
}
c = (
    PictorialBar()
    .add_xaxis(location)
    .add_yaxis(
        "",
        values,
        label_opts=opts.LabelOpts(is_show=False),
        symbol_size=18,
        symbol_repeat="p",
        symbol_offset=[0, 0],
        is_symbol_clip=True,
        symbol=png['ship'],
        color = 'rgb(226,137,234)'
    )
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="PictorialBar-各省份人口数量（虚假数据）"),
        xaxis_opts=opts.AxisOpts(is_show=False),
        yaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_show=False),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(opacity=0)
            ),
        ),
    )
    # .render("pictorialbar_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3bcd37527a6f431cb7c0df8b1c78971e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3bcd37527a6f431cb7c0df8b1c78971e = echarts.init(
#                     document.getElementById('3bcd37527a6f431cb7c0df8b1c78971e'), 'white', {renderer: 'canvas'});
#                 var option_3bcd37527a6f431cb7c0df8b1c78971e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "rgb(226,137,234)",
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "path://M16.678,17.086h9.854l-2.703,5.912c5.596,2.428,11.155,5.575,16.711,8.607c3.387,1.847,6.967,3.75,10.541,5.375 v-6.16l-4.197-2.763v-5.318L33.064,12.197h-11.48L20.43,15.24h-4.533l-1.266,3.286l0.781,0.345L16.678,17.086z M49.6,31.84 l0.047,1.273L27.438,20.998l0.799-1.734L49.6,31.84z M33.031,15.1l12.889,8.82l0.027,0.769L32.551,16.1L33.031,15.1z M22.377,14.045 h9.846l-1.539,3.365l-2.287-1.498h1.371l0.721-1.352h-2.023l-0.553,1.037l-0.541-0.357h-0.34l0.359-0.684h-2.025l-0.361,0.684 h-3.473L22.377,14.045z M23.695,20.678l-0.004,0.004h0.004V20.678z M24.828,18.199h-2.031l-0.719,1.358h2.029L24.828,18.199z  M40.385,34.227c-12.85-7.009-25.729-14.667-38.971-12.527c1.26,8.809,9.08,16.201,8.213,24.328 c-0.553,4.062-3.111,0.828-3.303,7.137c15.799,0,32.379,0,48.166,0l0.066-4.195l1.477-7.23 C50.842,39.812,45.393,36.961,40.385,34.227z M13.99,35.954c-1.213,0-2.195-1.353-2.195-3.035c0-1.665,0.98-3.017,2.195-3.017 c1.219,0,2.195,1.352,2.195,3.017C16.186,34.604,15.213,35.954,13.99,35.954z M23.691,20.682h-2.02l-0.588,1.351h2.023 L23.691,20.682z M19.697,18.199l-0.721,1.358h2.025l0.727-1.358H19.697z",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "p",
#             "symbolClip": true,
#             "data": [
#                 2681567.469,
#                 4137415.093,
#                 4684506.442,
#                 2447301.017,
#                 815039.596,
#                 1303124.508
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e1c\u5317",
#                 "\u4e2d\u5357",
#                 "\u534e\u4e1c",
#                 "\u534e\u5317",
#                 "\u897f\u5317",
#                 "\u897f\u5357"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "PictorialBar-\u5404\u7701\u4efd\u4eba\u53e3\u6570\u91cf\uff08\u865a\u5047\u6570\u636e\uff09",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_3bcd37527a6f431cb7c0df8b1c78971e.setOption(option_3bcd37527a6f431cb7c0df8b1c78971e);
#         });
#     </script>

# %% [markdown]
# ### 词云图

# %%
import pyecharts.options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import ThemeType
"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://gallery.echartsjs.com/editor.html?c=xS1jMxuOVm

目前无法实现的功能:

1、暂无
"""

data = [
    ("生活资源", "999"),
    ("供热管理", "888"),
    ("供气质量", "777"),
    ("生活用水管理", "688"),
    ("一次供水问题", "588"),
    ("交通运输", "516"),
    ("城市交通", "515"),
    ("环境保护", "483"),
    ("房地产管理", "462"),
    ("城乡建设", "449"),
    ("社会保障与福利", "429"),
    ("社会保障", "407"),
    ("文体与教育管理", "406"),
    ("公共安全", "406"),
    ("公交运输管理", "386"),
    ("出租车运营管理", "385"),
    ("供热管理", "375"),
    ("市容环卫", "355"),
    ("自然资源管理", "355"),
    ("粉尘污染", "335"),
    ("噪声污染", "324"),
    ("土地资源管理", "304"),
    ("物业服务与管理", "304"),
    ("医疗卫生", "284"),
    ("粉煤灰污染", "284"),
    ("占道", "284"),
    ("供热发展", "254"),
    ("农村土地规划管理", "254"),
    ("生活噪音", "253"),
    ("供热单位影响", "253"),
    ("城市供电", "223"),
    ("房屋质量与安全", "223"),
    ("大气污染", "223"),
    ("房屋安全", "223"),
    ("文化活动", "223"),
    ("拆迁管理", "223"),
    ("公共设施", "223"),
    ("供气质量", "223"),
    ("供电管理", "223"),
    ("燃气管理", "152"),
    ("教育管理", "152"),
    ("医疗纠纷", "152"),
    ("执法监督", "152"),
    ("设备安全", "152"),
    ("政务建设", "152"),
    ("县区、开发区", "152"),
    ("宏观经济", "152"),
    ("教育管理", "112"),
    ("社会保障", "112"),
    ("生活用水管理", "112"),
    ("物业服务与管理", "112"),
    ("分类列表", "112"),
    ("农业生产", "112"),
    ("二次供水问题", "112"),
    ("城市公共设施", "92"),
    ("拆迁政策咨询", "92"),
    ("物业服务", "92"),
    ("物业管理", "92"),
    ("社会保障保险管理", "92"),
    ("低保管理", "92"),
    ("文娱市场管理", "72"),
    ("城市交通秩序管理", "72"),
    ("执法争议", "72"),
    ("商业烟尘污染", "72"),
    ("占道堆放", "71"),
    ("地上设施", "71"),
    ("水质", "71"),
    ("无水", "71"),
    ("供热单位影响", "71"),
    ("人行道管理", "71"),
    ("主网原因", "71"),
    ("集中供热", "71"),
    ("客运管理", "71"),
    ("国有公交（大巴）管理", "71"),
    ("工业粉尘污染", "71"),
    ("治安案件", "71"),
    ("压力容器安全", "71"),
    ("身份证管理", "71"),
    ("群众健身", "41"),
    ("工业排放污染", "41"),
    ("破坏森林资源", "41"),
    ("市场收费", "41"),
    ("生产资金", "41"),
    ("生产噪声", "41"),
    ("农村低保", "41"),
    ("劳动争议", "41"),
    ("劳动合同争议", "41"),
    ("劳动报酬与福利", "41"),
    ("医疗事故", "21"),
    ("停供", "21"),
    ("基础教育", "21"),
    ("职业教育", "21"),
    ("物业资质管理", "21"),
    ("拆迁补偿", "21"),
    ("设施维护", "21"),
    ("市场外溢", "11"),
    ("占道经营", "11"),
    ("树木管理", "11"),
    ("农村基础设施", "11"),
    ("无水", "11"),
    ("供气质量", "11"),
    ("停气", "11"),
    ("市政府工作部门（含部门管理机构、直属单位）", "11"),
    ("燃气管理", "11"),
    ("市容环卫", "11"),
    ("新闻传媒", "11"),
    ("人才招聘", "11"),
    ("市场环境", "11"),
    ("行政事业收费", "11"),
    ("食品安全与卫生", "11"),
    ("城市交通", "11"),
    ("房地产开发", "11"),
    ("房屋配套问题", "11"),
    ("物业服务", "11"),
    ("物业管理", "11"),
    ("占道", "11"),
    ("园林绿化", "11"),
    ("户籍管理及身份证", "11"),
    ("公交运输管理", "11"),
    ("公路（水路）交通", "11"),
    ("房屋与图纸不符", "11"),
    ("有线电视", "11"),
    ("社会治安", "11"),
    ("林业资源", "11"),
    ("其他行政事业收费", "11"),
    ("经营性收费", "11"),
    ("食品安全与卫生", "11"),
    ("体育活动", "11"),
    ("有线电视安装及调试维护", "11"),
    ("低保管理", "11"),
    ("劳动争议", "11"),
    ("社会福利及事务", "11"),
    ("一次供水问题", "11"),
]


(
    WordCloud()
    .add(series_name="热点分析", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="热点分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
#     .render("basic_wordcloud.html")
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="b891629dd1a144e8a2940bad843c2028" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_b891629dd1a144e8a2940bad843c2028 = echarts.init(
#                     document.getElementById('b891629dd1a144e8a2940bad843c2028'), 'white', {renderer: 'canvas'});
#                 var option_b891629dd1a144e8a2940bad843c2028 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u70b9\u5206\u6790",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u751f\u6d3b\u8d44\u6e90",
#                     "value": "999",
#                     "textStyle": {
#                         "color": "rgb(119,112,39)"
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u70ed\u7ba1\u7406",
#                     "value": "888",
#                     "textStyle": {
#                         "color": "rgb(109,117,85)"
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u6c14\u8d28\u91cf",
#                     "value": "777",
#                     "textStyle": {
#                         "color": "rgb(60,1,126)"
#                     }
#                 },
#                 {
#                     "name": "\u751f\u6d3b\u7528\u6c34\u7ba1\u7406",
#                     "value": "688",
#                     "textStyle": {
#                         "color": "rgb(25,141,12)"
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u6b21\u4f9b\u6c34\u95ee\u9898",
#                     "value": "588",
#                     "textStyle": {
#                         "color": "rgb(32,31,160)"
#                     }
#                 },
#                 {
#                     "name": "\u4ea4\u901a\u8fd0\u8f93",
#                     "value": "516",
#                     "textStyle": {
#                         "color": "rgb(22,65,147)"
#                     }
#                 },
#                 {
#                     "name": "\u57ce\u5e02\u4ea4\u901a",
#                     "value": "515",
#                     "textStyle": {
#                         "color": "rgb(19,77,11)"
#                     }
#                 },
#                 {
#                     "name": "\u73af\u5883\u4fdd\u62a4",
#                     "value": "483",
#                     "textStyle": {
#                         "color": "rgb(14,36,113)"
#                     }
#                 },
#                 {
#                     "name": "\u623f\u5730\u4ea7\u7ba1\u7406",
#                     "value": "462",
#                     "textStyle": {
#                         "color": "rgb(65,145,123)"
#                     }
#                 },
#                 {
#                     "name": "\u57ce\u4e61\u5efa\u8bbe",
#                     "value": "449",
#                     "textStyle": {
#                         "color": "rgb(153,24,99)"
#                     }
#                 },
#                 {
#                     "name": "\u793e\u4f1a\u4fdd\u969c\u4e0e\u798f\u5229",
#                     "value": "429",
#                     "textStyle": {
#                         "color": "rgb(92,6,108)"
#                     }
#                 },
#                 {
#                     "name": "\u793e\u4f1a\u4fdd\u969c",
#                     "value": "407",
#                     "textStyle": {
#                         "color": "rgb(24,158,113)"
#                     }
#                 },
#                 {
#                     "name": "\u6587\u4f53\u4e0e\u6559\u80b2\u7ba1\u7406",
#                     "value": "406",
#                     "textStyle": {
#                         "color": "rgb(13,68,158)"
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5171\u5b89\u5168",
#                     "value": "406",
#                     "textStyle": {
#                         "color": "rgb(88,2,35)"
#                     }
#                 },
#                 {
#                     "name": "\u516c\u4ea4\u8fd0\u8f93\u7ba1\u7406",
#                     "value": "386",
#                     "textStyle": {
#                         "color": "rgb(19,73,157)"
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u79df\u8f66\u8fd0\u8425\u7ba1\u7406",
#                     "value": "385",
#                     "textStyle": {
#                         "color": "rgb(32,140,59)"
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u70ed\u7ba1\u7406",
#                     "value": "375",
#                     "textStyle": {
#                         "color": "rgb(131,106,76)"
#                     }
#                 },
#                 {
#                     "name": "\u5e02\u5bb9\u73af\u536b",
#                     "value": "355",
#                     "textStyle": {
#                         "color": "rgb(159,31,69)"
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u7136\u8d44\u6e90\u7ba1\u7406",
#                     "value": "355",
#                     "textStyle": {
#                         "color": "rgb(100,78,80)"
#                     }
#                 },
#                 {
#                     "name": "\u7c89\u5c18\u6c61\u67d3",
#                     "value": "335",
#                     "textStyle": {
#                         "color": "rgb(81,23,56)"
#                     }
#                 },
#                 {
#                     "name": "\u566a\u58f0\u6c61\u67d3",
#                     "value": "324",
#                     "textStyle": {
#                         "color": "rgb(157,33,63)"
#                     }
#                 },
#                 {
#                     "name": "\u571f\u5730\u8d44\u6e90\u7ba1\u7406",
#                     "value": "304",
#                     "textStyle": {
#                         "color": "rgb(13,51,148)"
#                     }
#                 },
#                 {
#                     "name": "\u7269\u4e1a\u670d\u52a1\u4e0e\u7ba1\u7406",
#                     "value": "304",
#                     "textStyle": {
#                         "color": "rgb(104,140,7)"
#                     }
#                 },
#                 {
#                     "name": "\u533b\u7597\u536b\u751f",
#                     "value": "284",
#                     "textStyle": {
#                         "color": "rgb(141,68,54)"
#                     }
#                 },
#                 {
#                     "name": "\u7c89\u7164\u7070\u6c61\u67d3",
#                     "value": "284",
#                     "textStyle": {
#                         "color": "rgb(80,11,12)"
#                     }
#                 },
#                 {
#                     "name": "\u5360\u9053",
#                     "value": "284",
#                     "textStyle": {
#                         "color": "rgb(5,51,13)"
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u70ed\u53d1\u5c55",
#                     "value": "254",
#                     "textStyle": {
#                         "color": "rgb(115,36,142)"

# %%
data1.head()
# Out:
#    行 ID            订单 ID       订单日期       发货日期 邮寄方式     客户 ID 客户名称   细分  城市  \
# 0     1  US-2018-1357144 2018-04-27 2018-04-29   二级  曾惠-14485   曾惠   公司  杭州
# 1     2  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者  内江
# 2     3  CN-2018-1973789 2018-06-15 2018-06-19  标准级  许安-10165   许安  消费者  内江
# 3     4  US-2018-3017568 2018-12-09 2018-12-13  标准级  宋良-17170   宋良   公司  镇江
# 4     5  CN-2017-2975416 2017-05-31 2017-06-02   二级  万兰-15730   万兰  消费者  汕头
#
#   省/自治区  国家  地区            产品 ID    类别  子类别                产品名称       销售额  数量  \
# 0    浙江  中国  华东  办公用-用品-10002717  办公用品   用品      Fiskars 剪刀, 蓝色   129.696   2
# 1    四川  中国  西南  办公用-信封-10004832  办公用品   信封  GlobeWeis 搭扣信封, 红色   125.440   2
# 2    四川  中国  西南  办公用-装订-10001505  办公用品  装订机  Cardinal 孔加固材料, 回收    31.920   2
# 3    江苏  中国  华东  办公用-用品-10003746  办公用品   用品    Kleencut 开信刀, 工业   321.216   4
# 4    广东  中国  中南  办公用-器具-10003452  办公用品   器具  KitchenAid 搅拌机, 黑色  1375.920   3
#
#     折扣       利润
# 0  0.4  -60.704
# 1  0.0   42.560
# 2  0.4    4.200
# 3  0.4  -27.104
# 4  0.0  550.200

# %% [markdown]
# ### 分析热点省份

# %%
hot_print = data1[['省/自治区','销售额']].groupby('省/自治区').agg({'销售额':sum})
hot_print
# Out:
#                销售额
# 省/自治区
# 上海      582450.568
# 云南      360925.768
# 内蒙古     273453.012
# 北京      409147.200
# 吉林      640196.571
# 四川      400877.596
# 天津      549906.630
# 宁夏       58121.000
# 安徽      628965.190
# 山东     1586782.988
# 山西      423878.770
# 广东     1452929.513
# 广西      377653.829
# 新疆       70097.020
# 江苏      649967.220
# 江西      237328.700
# 河北      790915.405
# 河南      853574.799
# 浙江      452108.244
# 海南      169256.843
# 湖北      621960.332
# 湖南      723442.209
# 甘肃      179270.028
# 福建      546903.532
# 西藏       10015.180
# 贵州      108141.600
# 辽宁      862569.736
# 重庆      361761.932
# 陕西      457688.168
# 青海       49863.380
# 黑龙江    1178801.162

# %%
x_data = hot_print.index.tolist()
y_data = hot_print['销售额'].tolist()
list_ = []
for i in range(len(x_data)):
    list_.append((x_data[i],int(y_data[i])))
list_
# Out:
# [('上海', 582450),
#  ('云南', 360925),
#  ('内蒙古', 273453),
#  ('北京', 409147),
#  ('吉林', 640196),
#  ('四川', 400877),
#  ('天津', 549906),
#  ('宁夏', 58121),
#  ('安徽', 628965),
#  ('山东', 1586782),
#  ('山西', 423878),
#  ('广东', 1452929),
#  ('广西', 377653),
#  ('新疆', 70097),
#  ('江苏', 649967),
#  ('江西', 237328),
#  ('河北', 790915),
#  ('河南', 853574),
#  ('浙江', 452108),
#  ('海南', 169256),
#  ('湖北', 621960),
#  ('湖南', 723442),
#  ('甘肃', 179270),
#  ('福建', 546903),
#  ('西藏', 10015),
#  ('贵州', 108141),
#  ('辽宁', 862569),
#  ('重庆', 361761),
#  ('陕西', 457688),
#  ('青海', 49863),
#  ('黑龙江', 1178801)]

# %%
data = list_
(
    WordCloud(
        init_opts = opts.InitOpts(theme = ThemeType.WONDERLAND),
    )
    .add(series_name="热点分析", data_pair=data, word_size_range=[6, 66])
    .set_global_opts(
#         init_opts = opts.InitOpts(theme = ThemeType.DARK),
        title_opts=opts.TitleOpts(
            title="热点分析", title_textstyle_opts=opts.TextStyleOpts(font_size=23)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
#     .render("basic_wordcloud.html")
).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'wonderland':'https://assets.pyecharts.org/assets/themes/wonderland'
#         }
#     });
# </script>
#
#         <div id="105bed94c5354020a8fa0f46826318c7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud', 'wonderland'], function(echarts) {
#                 var chart_105bed94c5354020a8fa0f46826318c7 = echarts.init(
#                     document.getElementById('105bed94c5354020a8fa0f46826318c7'), 'wonderland', {renderer: 'canvas'});
#                 var option_105bed94c5354020a8fa0f46826318c7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u70b9\u5206\u6790",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 582450,
#                     "textStyle": {
#                         "color": "rgb(132,37,151)"
#                     }
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 360925,
#                     "textStyle": {
#                         "color": "rgb(148,88,86)"
#                     }
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 273453,
#                     "textStyle": {
#                         "color": "rgb(17,54,143)"
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 409147,
#                     "textStyle": {
#                         "color": "rgb(147,33,151)"
#                     }
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 640196,
#                     "textStyle": {
#                         "color": "rgb(70,87,108)"
#                     }
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 400877,
#                     "textStyle": {
#                         "color": "rgb(48,19,145)"
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 549906,
#                     "textStyle": {
#                         "color": "rgb(28,43,4)"
#                     }
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 58121,
#                     "textStyle": {
#                         "color": "rgb(80,78,30)"
#                     }
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 628965,
#                     "textStyle": {
#                         "color": "rgb(123,155,36)"
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1586782,
#                     "textStyle": {
#                         "color": "rgb(157,89,59)"
#                     }
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 423878,
#                     "textStyle": {
#                         "color": "rgb(118,66,17)"
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1452929,
#                     "textStyle": {
#                         "color": "rgb(144,123,92)"
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 377653,
#                     "textStyle": {
#                         "color": "rgb(35,93,66)"
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 70097,
#                     "textStyle": {
#                         "color": "rgb(96,40,26)"
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 649967,
#                     "textStyle": {
#                         "color": "rgb(44,96,113)"
#                     }
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 237328,
#                     "textStyle": {
#                         "color": "rgb(15,122,44)"
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 790915,
#                     "textStyle": {
#                         "color": "rgb(123,80,25)"
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 853574,
#                     "textStyle": {
#                         "color": "rgb(37,29,1)"
#                     }
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 452108,
#                     "textStyle": {
#                         "color": "rgb(144,79,40)"
#                     }
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 169256,
#                     "textStyle": {
#                         "color": "rgb(57,19,78)"
#                     }
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 621960,
#                     "textStyle": {
#                         "color": "rgb(142,85,14)"
#                     }
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 723442,
#                     "textStyle": {
#                         "color": "rgb(81,133,23)"
#                     }
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 179270,
#                     "textStyle": {
#                         "color": "rgb(80,37,136)"
#                     }
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 546903,
#                     "textStyle": {
#                         "color": "rgb(146,28,56)"
#                     }
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 10015,
#                     "textStyle": {
#                         "color": "rgb(40,146,5)"
#                     }
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 108141,
#                     "textStyle": {
#                         "color": "rgb(43,54,75)"
#                     }
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 862569,
#                     "textStyle": {
#                         "color": "rgb(118,13,79)"
#                     }
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 361761,
#                     "textStyle": {
#                         "color": "rgb(31,112,96)"
#                     }
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 457688,
#                     "textStyle": {
#                         "color": "rgb(137,124,77)"
#                     }
#                 },
#                 {
#                     "name":

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line
from pyecharts.faker import Faker

bar = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
)
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
        legend_opts=opts.LegendOpts(pos_top="48%"),
    )
)

grid = (
    Grid()
    .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
    .add(line, grid_opts=opts.GridOpts(pos_top="60%"))
#     .render("grid_vertical.html")
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5c656aa8ec1740edb9f43b92ecb9e2a9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5c656aa8ec1740edb9f43b92ecb9e2a9 = echarts.init(
#                     document.getElementById('5c656aa8ec1740edb9f43b92ecb9e2a9'), 'white', {renderer: 'canvas'});
#                 var option_5c656aa8ec1740edb9f43b92ecb9e2a9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 102,
#                 111,
#                 89,
#                 83,
#                 98,
#                 59,
#                 35
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 21,
#                 86,
#                 26,
#                 123,
#                 93,
#                 52,
#                 118
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     70
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     52
#                 ],
#                 [
#                     "\u8001\u864e",
#                     87
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     60
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     138
#                 ],
#                 [
#                     "\u718a\u732b",
#                     45
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     60
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     115
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     93
#                 ],
#                 [
#                     "\u8001\u864e",
#                     44
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     50
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     139
#                 ],
#                 [
#                     "\u718a\u732b",
#                     50
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     50
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "top": "48%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showCo

# %% [markdown]
# ## 百度地图

# %%
from pyecharts import options as opts
from pyecharts.charts import BMap
from pyecharts.faker import Faker

c = (
    BMap()
    .add_schema(baidu_ak="53oVIOgmSIejwV7EfphPgTynOZbIiVYu", center=[120.13066322374, 30.240018034923])
    .add(
        "bmap",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        label_opts=opts.LabelOpts(formatter="{b}"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="BMap-基本示例"))
#     .render("bmap_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'bmap':'https://assets.pyecharts.org/assets/bmap.min', 'baidu_map_api71':'https://api.map.baidu.com/api?v=2.0&ak=53oVIOgmSIejwV7EfphPgTynOZbIiVYu', 'baidu_map_api77':'https://api.map.baidu.com/getscript?v=2.0&ak=53oVIOgmSIejwV7EfphPgTynOZbIiVYu'
#         }
#     });
# </script>
#
#         <div id="4a7fe602be9e4923b590868b484b78b8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'bmap', 'baidu_map_api71', 'baidu_map_api77'], function(echarts) {
#                 var chart_4a7fe602be9e4923b590868b484b78b8 = echarts.init(
#                     document.getElementById('4a7fe602be9e4923b590868b484b78b8'), 'white', {renderer: 'canvas'});
#                 var option_4a7fe602be9e4923b590868b484b78b8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "bmap",
#             "coordinateSystem": "bmap",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         51
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": [
#                         116.4,
#                         39.9,
#                         72
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": [
#                         121.47,
#                         31.23,
#                         149
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         48
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         116
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         29
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "bmap"
#             ],
#             "selected": {
#                 "bmap": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "BMap-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "bmap": {
#         "center": [
#             120.13066322374,
#             30.240018034923
#         ],
#         "roam": true
#     }
# };
#                 chart_4a7fe602be9e4923b590868b484b78b8.setOption(option_4a7fe602be9e4923b590868b484b78b8);
#                     var bmap = chart_4a7fe602be9e4923b590868b484b78b8.getModel().getComponent('bmap').getBMap();
#                     bmap.addControl(new BMap.MapTypeControl());
#         });
#     </script>

# %% [markdown]
# ## 箱型图

# %%
from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880, 1000, 980],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840, 830, 790],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760, 910, 920],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"])
c.add_yaxis("A", c.prepare_data(v1))
c.add_yaxis("B", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
# c.render("boxplot_base.html")
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5898d6523d3e4de591865e27f943427a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5898d6523d3e4de591865e27f943427a = echarts.init(
#                     document.getElementById('5898d6523d3e4de591865e27f943427a'), 'white', {renderer: 'canvas'});
#                 var option_5898d6523d3e4de591865e27f943427a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     740,
#                     857.5,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     790,
#                     832.5,
#                     880.0,
#                     940.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     740,
#                     760.0,
#                     805.0,
#                     872.5,
#                     920
#                 ],
#                 [
#                     760,
#                     795.0,
#                     815.0,
#                     865.0,
#                     890
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_5898d6523d3e4de591865e27f943427a.setOption(option_5898d6523d3e4de591865e27f943427a);
#         });
#     </script>

# %%
data4 = pd.read_excel('./data/箱形图2.xlsx')
data4
# Out:
#      电脑品牌  IBM   联想   戴尔   小米   宏碁   华为
# 0  2017Q4  770  566  222  344  343  110
# 1  2018Q1  450  700  778  346  554   99
# 2  2018Q2  775  800  554  477  223  130
# 3  2018Q3  600  690  555  576  530  200
# 4  2018Q4  732  760  600  431  660  323
# 5  2019Q1  763  573  621  440  539  353
# 6  2019Q2  821  775  480  616  300  400
# 7  2019Q3  763  840  721  570  340  461
# 8  2019Q4  654  750  600  521  367  536

# %%
v1 = [data4['IBM'].tolist()]
v2 = [data4['联想'].tolist()]
v3 = [data4['戴尔'].tolist()]
v4 = [data4['小米'].tolist()]
v5 = [data4['宏碁'].tolist()]
v6 = [data4['华为'].tolist()]
c = Boxplot()
c.add_xaxis(["expr1"])
c.add_yaxis("IBM", c.prepare_data(v1))
c.add_yaxis("联想", c.prepare_data(v2))
c.add_yaxis("戴尔", c.prepare_data(v3))
c.add_yaxis("小米", c.prepare_data(v4))
c.add_yaxis("宏碁", c.prepare_data(v5))
c.add_yaxis("华为", c.prepare_data(v6))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7dc39449b42d4e1da89196e3682e1e84" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7dc39449b42d4e1da89196e3682e1e84 = echarts.init(
#                     document.getElementById('7dc39449b42d4e1da89196e3682e1e84'), 'white', {renderer: 'canvas'});
#                 var option_7dc39449b42d4e1da89196e3682e1e84 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "IBM",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     450,
#                     627.0,
#                     763,
#                     772.5,
#                     821
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u8054\u60f3",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     566,
#                     631.5,
#                     750,
#                     787.5,
#                     840
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u6234\u5c14",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     222,
#                     517.0,
#                     600,
#                     671.0,
#                     778
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u5c0f\u7c73",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     344,
#                     388.5,
#                     477,
#                     573.0,
#                     616
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u5b8f\u7881",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     223,
#                     320.0,
#                     367,
#                     546.5,
#                     660
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "\u534e\u4e3a",
#             "boxWidth": [
#                 7,
#                 50
#             ],
#             "selected_mode": false,
#             "data": [
#                 [
#                     99,
#                     120.0,
#                     323,
#                     430.5,
#                     536
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "IBM",
#                 "\u8054\u60f3",
#                 "\u6234\u5c14",
#                 "\u5c0f\u7c73",
#                 "\u5b8f\u7881",
#                 "\u534e\u4e3a"
#             ],
#             "selected": {
#                 "IBM": true,
#                 "\u8054\u60f3": true,
#                 "\u6234\u5c14": true,
#                 "\u5c0f\u7c73": true,
#                 "\u5b8f\u7881": true,
#                 "\u534e\u4e3a": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {

# %% [markdown]
# ### 仪表盘

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

c = (
    Gauge()
    .add("", [("完成率", 99.9)])
    .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
    # .render("gauge_base.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="98df014d800d4b29af908d2c43a38429" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_98df014d800d4b29af908d2c43a38429 = echarts.init(
#                     document.getElementById('98df014d800d4b29af908d2c43a38429'), 'white', {renderer: 'canvas'});
#                 var option_98df014d800d4b29af908d2c43a38429 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     "0%",
#                     "20%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0,
#                 "overflow": "none",
#                 "valueAnimation": true
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 0,
#                 "borderColor": "transparent",
#                 "offsetCenter": [
#                     "0%",
#                     "40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "#464646",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0,
#                 "overflow": "none",
#                 "valueAnimation": true
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 99.9
#                 }
#             ],
#             "progress": {
#                 "show": false,
#                 "overlap": true,
#                 "width": 10,
#                 "roundCap": false,
#                 "clip": false
#             },
#             "anchor": {
#                 "show": true,
#                 "showAbove": false,
#                 "size": 6,
#                 "icon": "circle",
#                 "offsetCenter": [
#                     0,
#                     0
#                 ],
#                 "keepAspect": false
#             },
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_98df014d800d4b29af908d2c43a38429.setOption(option_98df014d800d4b29af908d2c43a38429);
#         });
#     </script>
